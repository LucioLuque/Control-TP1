# %% [markdown]
# # Ej 1

# %% [markdown]
# ## Parte A)

# %% [markdown]
# ### a)

# %% [markdown]
# $I(s)(L+R)+K_{e}s\theta(s)=V(s)$
#
#
# $Js²\theta(s)+ Bs\theta(s)=K_tI(s)$
#
# $\frac{Js²\theta(s)+ Bs\theta(s)}{K_t}=I(s)$
#
#
# $\frac{Js²\theta(s)+ Bs\theta(s)}{K_t}(L+R)+K_{e}s\theta(s)=V(s)$
#
# $\theta(s)(\frac{Js²+ Bs}{K_t}(L+R)+K_{e}s)=V(s)$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{K_t}{s[s²LJ +s(LB + RJ) + K_tK_e + RB ]}$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{0.25}{s[s²0.15*0.02 +s(0.15*0.25 + 0.7*0.02) + 0.25*0.1 + 0.7*0.25 ]}$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{0.25}{s[0.003s² + 0.0515s + 0.2]}$

# %% [markdown]
# ### b)

# %%
import control as ctrl
a = 0.25
b = 0.003
c = 0.0515
d = 0.2

num = [a]
den = [b, c, d, 0]

G = ctrl.TransferFunction(num, den)

gm, pm, wg, wp = ctrl.margin(G)

print("Margen de ganancia:", gm)
print("Margen de fase:", pm)
# Out:
# Margen de ganancia: 13.73333333333333
# Margen de fase: 72.22396219496937

# %% [markdown]
# ### c)

# %% [markdown]
# ### d)

# %% [markdown]
# ### e)
