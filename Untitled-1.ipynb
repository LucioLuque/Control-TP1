# %% [markdown]
# # Ej 1

# %% [markdown]
# ## Parte A)

# %% [markdown]
# ### a)

# %% [markdown]
# $I(s)(Ls+R)+K_{e}s\theta(s)=V(s)$
#
#
# $Js²\theta(s)+ Bs\theta(s)=K_tI(s)$
#
# $\frac{Js²\theta(s)+ Bs\theta(s)}{K_t}=I(s)$
#
#
# $\frac{Js²\theta(s)+ Bs\theta(s)}{K_t}(Ls+R)+K_{e}s\theta(s)=V(s)$
#
# $\theta(s)(\frac{Js²+ Bs}{K_t}(Ls+R)+K_{e}s)=V(s)$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{K_t}{s[s²LJ +s(LB + RJ) + K_tK_e + RB ]}$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{0.25}{s[s²0.15*0.02 +s(0.15*0.25 + 0.7*0.02) + 0.25*0.1 + 0.7*0.25 ]}$
#
# $G(s)=\frac{\theta(s)}{V(s)}=\frac{0.25}{s[0.003s² + 0.0515s + 0.2]}$

# %% [markdown]
# variables de estado

# %% [markdown]
# $$
# X_1 = i,\quad X_2 = \omega,\quad X_3 = \theta
# $$
#
# $$
# L\dot{X}_1 + R X_1 + K_e X_2 = V
# $$
#
# $$
# J\dot{X}_2 + B X_2 = K_t X_1
# $$
#
# $$
# \begin{bmatrix}
# \dot{X}_1 \\
# \dot{X}_2 \\
# \dot{X}_3
# \end{bmatrix}
# =
# \begin{bmatrix}
# -\frac{R}{L} & -\frac{K_e}{L} & 0 \\
# \frac{K_t}{J} & -\frac{B}{J} & 0 \\
# 0 & 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# X_1 \\
# X_2 \\
# X_3
# \end{bmatrix}
# +
# \begin{bmatrix}
# \frac{1}{L} \\
# 0 \\
# 0
# \end{bmatrix}
# V
# $$
#
#
# $$
# \begin{bmatrix}
# \dot{X}_1 \\
# \dot{X}_2 \\
# \dot{X}_3
# \end{bmatrix}
# =
# \begin{bmatrix}
# -\frac{0.7}{0.15} & -\frac{0.1}{0.15} & 0 \\
# 12.5 & -12.5 & 0 \\
# 0 & 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# X_1 \\
# X_2 \\
# X_3
# \end{bmatrix}
# +
# \begin{bmatrix}
# \frac{1}{0.15} \\
# 0 \\
# 0
# \end{bmatrix}
# V
# $$
#
#
# $$
# Y
# =
# \begin{bmatrix}
# 0 & 0 & 1
# \end{bmatrix}
# \begin{bmatrix}
# X_1 \\
# X_2 \\
# X_3
# \end{bmatrix}
# $$

# %% [markdown]
# ### b)

# %%
import math

import control as ctrl
a = 0.25
b = 0.003
c = 0.0515
d = 0.2

num = [a]
den = [b, c, d, 0]

G = ctrl.TransferFunction(num, den)

gm, pm, wg, wp = ctrl.margin(G)

print(f"Margen de ganancia: {gm}, en db: {20 * math.log10(gm)} dB")
print(f"Margen de fase: {pm} grados")
# Out:
# Margen de ganancia: 13.73333333333333, en db: 22.755519226269442 dB
# Margen de fase: 72.22396219496937 grados

# %% [markdown]
# Dado que "valores adecuados (MG > 6 dB y MF ~30°−60°) aseguran que el sistema permanecerá estable frente a variaciones en los componentes o dinámica no modelada". Con nuestros valores no deberiamos introducir un compensador.

# %% [markdown]
# ### c)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# el N lo deberiamos poner como -??

# %% [markdown]
# $$E(s)=V(s)-\theta(s)-K_e\omega(s)$$
#
# $$I(s)=\frac{E(s)}{Ls + R}$$
#
# $$(Ls + R)I(s)=V(s)-\theta(s)-K_e\omega(s)$$
#
# $$\omega(s)=\frac{K_tI(s)+ N(s)}{Js + B}$$
#
# $$(Js + B)\omega(s)=K_tI(s)+ N(s)$$
#
# $$\theta(s)=\frac{\omega(s)}{s}$$
#
#
# $$(Ls + R)I(s)=V(s)-\theta(s)-K_es\theta(s)$$
#
# $$(Ls + R)I(s)=V(s)-(1+K_es)\theta(s)$$
#
# $$I(s)=\frac{V(s)-(1+K_es)\theta(s)}{Ls + R}$$
#
#
# $$(Js^2 + Bs)\theta(s)=K_t\frac{V(s)-(1+K_es)\theta(s)}{Ls + R}+ N(s)$$
#
#
# $$(Ls+R)(Js^2 + Bs)\theta(s)=K_tV(s)-K_t(1+K_es)\theta(s)+ (Ls +R)N(s)$$
#
# $$[K_t(1+K_es)(Ls+R)(Js^2 + Bs)]\theta(s)=K_tV(s) + (Ls +R)N(s)$$
#
# $$\theta(s)=\frac{K_t}{K_t(1+K_es)(Ls+R)(Js^2 + Bs)}V(s) + \frac{Ls +R}{K_t(1+K_es)(Ls+R)(Js^2 + Bs)}N(s)$$
#
# $$\theta(s)=\frac{\theta(s)}{V(s)}V(s) + \frac{\theta(s)}{N(s)}N(s)$$
#
#
# $$\frac{\theta(s)}{V(s)}=\frac{K_t}{K_t(1+K_es)(Ls+R)(Js^2 + Bs)}$$
#
# $$\frac{\theta(s)}{N(s)}=\frac{Ls +R}{K_t(1+K_es)(Ls+R)(Js^2 + Bs)}$$
#
#
# $$\frac{\theta(s)}{V(s)}=\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}$$
#
# $$\frac{\theta(s)}{N(s)}=\frac{0.15s + 0.7}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}$$
#
# $$\theta(s)=\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}V(s) + \frac{0.15s + 0.7}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}N(s)$$

# %% [markdown]
# es asi?

# %% [markdown]
# $$V(s) = \frac{1}{s} $$
# $$N(s) = \frac{0.1}{s} $$
#
#
# $$\theta(s)=\frac{0.25}{0.003s^4 + 0.0515s^3 + 0.2s^2+ 0.25s} + \frac{0.015s + 0.07}{0.003s^4 + 0.0515s^3 + 0.2s^2+ 0.25s}$$
#
#
#
# <!-- $$\theta(s)=\frac{0.015s + 0.32}{0.003s^4 + 0.0515s^3 + 0.2s^2+ 0.25s}$$ -->

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

den = [0.003, 0.0515, 0.2, 0.25]

Tv = ctrl.TransferFunction([0.25], den)
Tn = ctrl.TransferFunction([-0.15, -0.7], den) # es menos??

t = np.linspace(0, 200, 1000)

t1, y_ref = ctrl.step_response(Tv, T=t)

t2, y_pert = ctrl.step_response(0.1 * Tn, T=t)

y_total = y_ref + y_pert

r = np.ones_like(t)

plt.figure(figsize=(10, 5))
plt.plot(t, y_total, label="Salida total $\\theta(t)$")
plt.plot(t, r, "r--", label="Referencia escalón unitario")

plt.plot(t, y_ref, "--", label="Aporte de la referencia")
plt.plot(t, y_pert, "--", label="Aporte de la perturbación")

plt.title("Salida del sistema con referencia y perturbación simultáneas")
plt.xlabel("Tiempo [s]")
plt.ylabel("Salida")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### d)

# %% [markdown]
# $$V(s) = \frac{1}{s^2} $$
# $$N(s) = \frac{0.1}{s} $$
#
#
# $$\theta(s)=\frac{0.25}{0.003s^5 + 0.0515s^4 + 0.2s^3+ 0.25s^2} + \frac{0.015s + 0.07}{0.003s^4 + 0.0515s^3 + 0.2s^2+ 0.25s}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

den = [0.003, 0.0515, 0.2, 0.25]

Tv = ctrl.TransferFunction([0.25], den)
Tn = ctrl.TransferFunction([-0.15, -0.7], den) # es menos??

t = np.linspace(0, 200, 1000)
r = t

t1, y_ref = ctrl.forced_response(Tv, T=t, U=r)

t2, y_pert = ctrl.step_response(0.1 * Tn, T=t)

y_total = y_ref + y_pert

plt.figure(figsize=(10, 5))
plt.plot(t, y_total, label="Salida total $\\theta(t)$")
plt.plot(t, r, "r--", label="Referencia rampa unitaria")

plt.plot(t, y_ref, "--", label="Aporte de la referencia")
plt.plot(t, y_pert, "--", label="Aporte de la perturbación")

plt.title("Salida del sistema con referencia y perturbación simultáneas")
plt.xlabel("Tiempo [s]")
plt.ylabel("Salida")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### e)

# %% [markdown]
# Para el caso de la referencia de tipo escalon se deberia introducir el siguiente compensador ...
#
# Para el caso de la referencia de tipo rampa se deberia introducir el siguiente compensador ...

# %% [markdown]
# ## Parte B)

# %%
$Lo dejo por las dudas pero estaba haciendo algo mal

# ts <= 7.5
# Mp <= 15

# $$M_p \geq e^{-\pi\frac{\zeta}{\sqrt{1-\zeta^2}}}$$

# $$\zeta \geq -\frac{\ln(M_p)}{\sqrt{\pi^2+\ln(M_p)^2}}$$


# $$\zeta \geq -\frac{\ln(0.15)}{\sqrt{\pi^2+\ln(0.15)^2}}$$

# $$\zeta \geq 0.6$$


# $$t_s>=\frac{4}{\zeta\omega_n}$$

# $$\omega_n \geq \frac{4}{7.5\zeta}$$

# $$\omega_n \geq 0.888$$

# %% [markdown]
# $$G(s)=\frac{\theta(s)}{V(s)}=\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}$$
# $$Y(s)=\frac{G(s)}{s}$$
#
#
# $$y_{ss}=\lim_{t \to \infty}y(t)=\lim_{s \to 0}sY(s)$$
#
# $$y_{ss}=\lim_{t \to \infty}y(t)=\lim_{s \to 0}sY(s)$$
#
#
# $$y_{ss}=\lim_{s \to 0}\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}=1$$
#
# luego vemos polos
#
# $$s_1=-12.296$$
#
# $$s_{2,3}=-2.435 \pm j 0.920 $$
#
#
# $$y(t)= 1 − 0.0691e^{−12.296t} − 0.9309e^{−2.435t}cos(0.920t) − 3.3875e^{−2.435t}sin(0.920t)$$

# %% [markdown]
# Intente hacerlo a mano pero es re largo y hay que aproximar, mejro lo hgao con python

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

G = ctrl.TransferFunction([0.25], [0.003, 0.0515, 0.2, 0])
T = ctrl.feedback(G, 1)
print(T)

t = np.linspace(0, 10, 1000)
t, y = ctrl.step_response(T, T=t)

y_ss = y[-1]
print("Valor final:", y_ss)

y_max = np.max(y)
Mp = (y_max - y_ss) / y_ss * 100

print("Valor máximo:", y_max)
print("Sobrepico Mp (%):", Mp)

upper = 1.02 * y_ss
lower = 0.98 * y_ss

outside = np.where((y < lower) | (y > upper))[0]

if len(outside) == 0:
    ts = 0
else:
    last_outside = outside[-1]
    if last_outside == len(t) - 1: 
        print("No se puede determinar ts")
    else:
        ts = t[last_outside + 1]

print("Tiempo de establecimiento ts (2%):", ts)

plt.figure(figsize=(10,6))
plt.plot(t, y, label='Respuesta al escalón')
plt.axhline(y_ss, linestyle='--', label='Valor final')
plt.axhline(upper, linestyle=':', label='Banda 2%')
plt.axhline(lower, linestyle=':')
plt.xlabel('Tiempo [s]')
plt.ylabel('Salida')
plt.title('Respuesta al escalón del sistema en lazo cerrado')
plt.grid(True)
plt.legend()
plt.show()


#Otra forma de hacerlo! mas rapida pero redondea!
# import control as ctrl

# G = ctrl.TransferFunction([0.25], [0.003, 0.0515, 0.2, 0])
# T = ctrl.feedback(G, 1)
# info = ctrl.step_info(T, SettlingTimeThreshold=0.02)
# print(info)
# print("ts =", info["SettlingTime"])
# print("Mp =", info["Overshoot"])
# Out:
# <TransferFunction>: sys[31]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#                   0.25
#   -------------------------------------
#   0.003 s^3 + 0.0515 s^2 + 0.2 s + 0.25
# Valor final: 1.0000000000040876
# Valor máximo: 1.0002374751065521
# Sobrepico Mp (%): 0.023747510246355314
# Tiempo de establecimiento ts (2%): 2.052052052052052

# %% [markdown]
# <!-- $$G(s)=\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}V(s) + \frac{0.15s + 0.7}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}N(s)$$ -->
#
# <!-- $$\frac{E(s)}{R(s)} = 1 - G(s)$$  -->
#
# <!--
# $$y_{ss}=\lim_{t \to \infty}y(t)=\lim_{s \to 0}sY(s)$$
#
# $$y_{ss}=\lim_{t \to \infty}y(t)=\lim_{s \to 0}sY(s)$$
#
#
# $$y_{ss}=\lim_{s \to 0}\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}=1$$ -->

# %% [markdown]
# Para la precision lo hago a mano

# %% [markdown]
# $$G(s)=\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}V(s) + \frac{0.15s + 0.7}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}N(s)$$
# $$\frac{E(s)}{R(s)}=1 - G(s)$$
#
#
# $$e_{ss}=\lim_{s \to 0}s\frac{E(s)}{R(s)}R(s)$$
#
# $$e_{ss}=\lim_{s \to 0} s[\frac{0.25}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}\frac{1}{s} + \frac{0.15s + 0.7}{0.003s^3 + 0.0515s^2 + 0.2s+ 0.25}\frac{0.2}{s}] - 1$$
#
# $$e_{ss}= [1 + \frac{0.7 * 0.2}{0.25}] -1 = 0.56$$
#
# $$e_{ss}= 56\%$$

# %% [markdown]
# ### b)

# %% [markdown]
# No cumple con la precision pedida!
# Segun lo que vimos yo pondria un PI, de ultima si se modifica mucho el transitorio haria un compensador en retraso un lag.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# En el ejercicio 1, parte b, item b), la idea es que hagan el diseño en forma analítica (como se hizo en clases). En lo posible no hagan diseños por fuerza bruta.
